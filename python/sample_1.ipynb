# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### This is a **sample line** of _Markdown_ language for ~some~ enhanced documentation.
# ___
# >Welcome To Jupyter Lab

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = 1
y = 2
z = x**2 + 2*x*y + y**2
z
# Out:
# 9

# %%
print(np.pi)
# Out:
# 3.141592653589793

# %%
x = np.linspace(0, 4, 101)
plt.plot(x, np.sqrt(x) * np.sin(x), linewidth = 1)
plt.plot(x, np.sqrt(x) * np.cos(x), linewidth = 1)
plt.show()
